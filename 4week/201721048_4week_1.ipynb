# %%
from google.colab import drive
drive.mount('./MyDrive')

# %%
# %cd /content/MyDrive/MyDrive/Plan_/data/train/fruits/
# !ls

# %%
# example of zoom image augmentation
from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import save_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot

# load the image
img = load_img('wild-blueberries-576x1024.jpg')
# convert to numpy array
data = img_to_array(img)
# expand dimension to one sample
samples = expand_dims(data, 0)

# create image data augmentation generator
datagen = ImageDataGenerator(
    width_shift_range=50,
    height_shift_range=50,
    rotation_range=90)
# prepare iterator
it = datagen.flow(samples, batch_size=1)

# generate samples and plot
for i in range(9):
    # define subplot
    pyplot.subplot(330 + 1 + i)
    # generate batch of images
    batch = it.next()
    # convert to unsigned integers for viewing
    image = batch[0].astype('uint8')
    fname = 'b3%d.png' % i
    save_img(fname,image)
    # plot raw pixel data
    pyplot.imshow(image)
    
# show the figure
pyplot.show()

# %% [markdown]
# shear_range를 수행한 결과, 해당 코드는 이미지를 시계방향로 회전시켜 이미지변환 역할을 하는 것을 알았고 해당 코드를 사용하면 이미지를 좌우로 옮기거나 돌리는 코드를 합쳐서 작성하지 않고 이미지의 변환을 줄 수 있어 여러 방면에서 활용도가 있을 것이라 생각한다.
